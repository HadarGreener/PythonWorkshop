# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# <a href="https://matplotlib.org">Maplotlib website </a>
# - examples
# - tutorials
# - list of plotting commands
#
# <a href="https://github.com/abostroem/2015-01-03-aas/blob/gh-pages/intermediate/matplotlib/Plotting%20with%20matplotlib.ipynb">Another plotting example notebook (by Phil Rosenfield)</a>
#
# ** Matplotlib rule: there are probably 5 ways to do what you're trying to do **

# %% [markdown]
# # Figures and Subplots
# <a href = "https://realpython.com/python-matplotlib-guide/">Source</a>

# %% [markdown]
# ![figure_subplots.png](attachment:figure_subplots.png)

# %% [markdown]
# ## Axis Objects

# %% [markdown]
# <a href = "https://matplotlib.org/gallery/showcase/anatomy.html?highlight=figure"> Matplotlib source</a>

# %% [markdown]
# ![anatomy_of_a_figure.jpg](attachment:anatomy_of_a_figure.jpg)

# %% [markdown]
# # Making the Skeleton

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1) #nrow, ncol, nsubplot
ax2 = fig.add_subplot(1,2,2)
ax_list = [ax1, ax2]

# %%
fig, ax_list = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# # Basic Plotting

# %% [markdown]
# Generate data

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y)

# %% [markdown]
# Let's make points

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y, 's', color='r')

# %% [markdown]
# ### Log axes

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y, 's')
ax.semilogx()
# Out:
# []

# %% [markdown]
# ### Scale Everything

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y, 's')
ax.set_xlim(-0.1, 1.1)
ax.set_ylim(-0.1, 1.1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Random Points')
# Out:
# Text(0.5, 1.0, 'Random Points')

# %% [markdown]
# # Scatter Plots
# <a href = "https://matplotlib.org/gallery/shapes_and_collections/scatter.html#sphx-glr-gallery-shapes-and-collections-scatter-py"> Source: Matplotlib example </a>

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.scatter(x, y)
plt.show()

# %% [markdown]
# ### color code

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
colors = np.random.rand(N) #values between 0--> represent values on a color map

#ax.scatter(x, y,c=colors,cmap='spring') #cmap gives the colors
ax.scatter(x, y,c=colors) #cmap gives the colors

#fig.colorbar() #comment out if delete cmap='spring'
plt.show()

# %% [markdown]
# ### Scale

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

ax.scatter(x, y, s=area, c=colors)
plt.show()

# %% [markdown]
# ### Change opacity

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Errorbars

# %% [markdown]
# generate data

# %%
x = np.arange(10)+np.random.randn(10)
y = np.arange(10)+np.random.randn(10)
xerr = np.random.randn(10)
yerr = np.random.randn(10)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.errorbar(x,y, yerr=yerr) #the third value is always interpreted as the yerror
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Let's clean that up

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.errorbar(x,y, yerr=yerr, fmt='o') #different syntax from plotting!!
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.errorbar(x,y, yerr=yerr, fmt='o', capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Add x errors

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.errorbar(x,y, yerr=yerr, xerr=xerr, fmt='o', capsize=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Legend

# %% [markdown]
# # generate data

# %%
x = np.arange(10)+np.random.randn(10)
y = x+np.random.randn(10)
y2 = x**2 + np.random.randn(10)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x, y, 'o', label='linear')
ax.plot(x, y2, 's', label='quadratic')
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
l1, = ax.plot(x, y, 'o', label='linear')
l2, = ax.plot(x, y2, 's', label='quadratic')
ax.legend([l1], ['linear only'])

# %% [markdown]
# # Historgram

# %% [markdown]
# generate data

# %%
x = np.ones(1000)+np.random.randn(1000)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
bin_edges, n, patches = ax.hist(x, bins=20)

# %% [markdown]
# ### lines

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
bin_edges, n, patches = ax.hist(x, bins=20)
ax.axvline(np.median(x), color='k')

# %% [markdown]
# # Show an Image

# %%
# Generate fake data
np.random.seed(0)
y, x = np.mgrid[:1024, :1024]
z = 2. * x ** 2 - 0.5 * x ** 2 + 1.5 * x * y - 1.
z += np.random.normal(0., 0.1, z.shape) * 50000.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.imshow(z)

# %% [markdown]
# ### Change the color map

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
im = ax.imshow(z, cmap='bone')

# %% [markdown]
# ### Change the contrast limits

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.imshow(z, cmap='bone', vmin=-20000, vmax=1E6)

# %% [markdown]
# ### Implement DS9 zscale

# %%
from astropy.visualization import ZScaleInterval

def zscale(img):
    zscale = ZScaleInterval()
    vmin, vmax = zscale.get_limits(img)
    return vmin, vmax

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
zscale_vmin, zscale_vmax = zscale(z)
ax.imshow(z, cmap='bone', vmin=zscale_vmin, vmax=zscale_vmax)

# %% [markdown]
# ### Add a colorbar

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
zscale_vmin, zscale_vmax = zscale(z)
im = ax.imshow(z, cmap='bone', vmin=zscale_vmin, vmax=zscale_vmax)
fig.colorbar(im)

# %% [markdown]
# # rcParams

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# %%
plt.rcParams['figure.figsize']=(3,3)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

# %% [markdown]
# # Styles

# %%
x = np.arange(10)+np.random.randn(10)
y = np.arange(10)+np.random.randn(10)

# %%
plt.style.use('default') #I can choose a predefined style of my choice

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y, 'o')

# %%
plt.style.use('ggplot') #A different style

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y, 'o')

# %% [markdown]
# # Exercise

# %%
x = np.linspace(0,1,100)*np.pi
y = np.sin(x)+np.random.randn(100)
y2 = np.cos(x)+np.random.randn(100)

# %% [markdown]
# 1. Plot the sine and cosine curves with diamond points
# 2. Set the linestyle to be dotted
# 3. Label the axes and set a title
# 4. Create a legend
# 5. Plot a horizontal line at y = 0

# %% [markdown]
# Bonus:
# 1. Create an array of residuals of the sine curve assuming the data represent a perfect sine
# 2. Create a figure with two subplots, placed vertically (nrow=2)
# 3. Plot the sine data in the top plot and label your axes and title
# 4. Plot the residuals in the bottom plot and label you axes and title
# 5. Find how to set the x axis such that when you change the limits on one plot it changes for both
